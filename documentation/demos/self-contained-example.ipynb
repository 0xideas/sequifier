# %%
import os
import shutil
import subprocess
import yaml
import numpy as np
import pandas as pd
import torch

# %%
PROJECT_ROOT = "sequifier-demo"
DATA_DIR = os.path.join(PROJECT_ROOT, "data")
CONFIG_DIR = os.path.join(PROJECT_ROOT, "configs")
OUTPUT_DIR = os.path.join(PROJECT_ROOT, "outputs")

os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(CONFIG_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
n_sequences = 100
seq_len = 128

np.random.seed(101)

records = []
for seq_id in range(n_sequences):
    start_num = np.random.randint(0, 5)
    for t in range(seq_len):
        val = ((start_num + t) % 5) + 1
        records.append(
            {
                "sequenceId": seq_id,
                "itemPosition": t,
                "targetToken": val,  # The categorical variable we want to predict
            }
        )

df = pd.DataFrame(records)
# Sequifier expects a specific format, usually csv or parquet
file_path = os.path.join(DATA_DIR, "synthetic-sequences.parquet")
df.to_parquet(file_path)

# %%
df.head()

# %%
def write_yaml(path, data):
    with open(path, "w") as f:
        yaml.dump(data, f, default_flow_style=False)

# %%
preprocess_config = {
    "project_root": PROJECT_ROOT,
    "preprocessing_data_path": file_path,
    "read_format": "parquet",
    "write_format": "parquet",
    "selected_columns": ["targetToken"],
    "split_ratios": [0.8, 0.1, 0.1],  # Train, Val, Test
    "window_length": 11,  # 10-token model context plus one future target
    "max_target_offset": 1,
    "window_strides": [1, 1, 1],  # Dense sampling
    "max_rows": None,
    "seed": 42,
}

pp_conf_path = os.path.join(CONFIG_DIR, "preprocess.yaml")
write_yaml(pp_conf_path, preprocess_config)

# %%
train_config = {
    "project_root": PROJECT_ROOT,
    "model_name": "demo-cycle-model",
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "global_training": {
        "read_format": "parquet",
        "training_objective": "causal",
        "context_length": 10,
        "inference_batch_size": 10,
        "batch_size": 32,
        "learning_rate": 0.001,
        "optimizer": {"name": "Adam"},
        "scheduler": {"name": "StepLR", "step_size": 1, "gamma": 0.99},
        "log_interval": 10000,
        "save_interval_epochs": 5,
        "torch_compile": "none",  # Keep the demo independent of a host C++ toolchain.
    },
    "model": {
        "backbone": {
            "architecture": {
                "dim_model": 16,
                "max_context_length": 10,
                "num_layers": 1,  # Tiny model for speed
                "attention": {"n_heads": 2},
                "feed_forward": {"dim": 32},
                "dropout": 0.0,
            },
        },
        "interface": {
            "input_columns": ["targetToken"],
            "target_columns": ["targetToken"],
            "ingestion": {
                "type": "embedding",
                "output_dim": 16,
                "feature_embedding_dims": {"targetToken": 16},
            },
            "decoder": {"type": "linear", "prediction_length": 1},
        },
    },
    "dataset": {
        # Metadata is generated by preprocessing from the input basename.
        "part": {
            "metadata_config_path": "configs/metadata_configs/synthetic-sequences.json"
        },
        "criterion": {"targetToken": "CrossEntropyLoss"},
    },
    "training_plan": {"epochs": 5},
    "evaluation": True,
    "export_generative_model": True,
    "export_embedding_model": False,
    "export_onnx": True,
    "export_pt": False,
}

tr_conf_path = os.path.join(CONFIG_DIR, "train.yaml")
write_yaml(tr_conf_path, train_config)

# %%
infer_config = {
    "project_root": PROJECT_ROOT,
    "model_type": "generative",
    # Training exports best and last artifacts with the final epoch in the filename.
    "model_path": "models/demo-cycle-model-best-5.onnx",
    "training_config_path": tr_conf_path,
    "dataset": "default",
    # Use the 'test' split created during preprocessing
    "data_path": "data/synthetic-sequences-split2.parquet",
    "write_format": "parquet",
    "output_probabilities": False,
    "decode_categories": True,  # Map integer classes back to original values (e.g., "1", "2")
    "device": "cpu",
    "inference_batch_size": 10,
    "autoregressive": True,
    "generation_steps": 5,  # Predict 5 steps into the future
}

inf_conf_path = os.path.join(CONFIG_DIR, "infer.yaml")
write_yaml(inf_conf_path, infer_config)

# %%
subprocess.run(["sequifier", "preprocess", "--config-path", pp_conf_path], check=True)

# %%
subprocess.run(["sequifier", "train", "--config-path", tr_conf_path], check=True)

# %%
subprocess.run(["sequifier", "infer", "--config-path", inf_conf_path], check=True)

# %%
pred_path = os.path.join(
    OUTPUT_DIR, "predictions", "demo-cycle-model-best-5", "part-000.parquet"
)

preds = pd.read_parquet(pred_path)

preds["targetToken"] = preds["targetToken"].astype(int)

print(f"Loaded predictions from: {pred_path}")
print(preds.head(3))

# %%
seq_vals = preds["sequenceId"].to_numpy()
token_vals = preds["targetToken"].to_numpy()

# Check whether each generated sequence follows the learned 1, 2, 3, 4, 5 cycle.
sequence_id_change = np.concatenate([[0], (seq_vals[1:] != seq_vals[:-1]).astype(int)])
correct_increment = np.concatenate(
    [[1], (token_vals[1:] == token_vals[:-1] + 1).astype(int)]
)
last_was_five = np.concatenate([[1], (token_vals[:-1] == 5).astype(int)])
is_one = token_vals == 1

# %%
# See what percentage of generated tokens conforms to the cycle rule.

mean_accuracy = (
    sequence_id_change | correct_increment | (last_was_five & is_one)
).mean()

print(f"{mean_accuracy*100:.2f}% of generated tokens follow the cycle rule")

# %%
print(f"Deleting demo project: {PROJECT_ROOT}")
shutil.rmtree(PROJECT_ROOT)
